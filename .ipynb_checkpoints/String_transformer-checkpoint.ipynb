# %%
str = '''
            'ballRecovery':
            'ballRecoveryPtn':
            'bigChanceCreated':
            'bigChanceCreatedPtn':
            'bigChanceMissed':
            'bigChanceMissedPtn':
            'bigChanceScored':
            'bigChanceScoredPtn':
            'bigChanceSucc':
            'bigChanceSuccPtn':
            'cardPtn':
            'clears':
            'clearsPtn':
            'competitionId':
            'competitionIdWs':
            'createTime':
            'defensiveThirdPass':
            'defensiveThirdPassAcc':
            'defensiveThirdPassSucc':
            'defensiveThirdPassSuccPtn':
            'dribbles':
            'dribblesPtn':
            'errorsSum':
            'errorsSumPtn':
            'fatalError':
            'finalThirdPass':
            'finalThirdPassAcc':
            'finalThirdPassSucc':
            'finalThirdPassSuccPtn':
            'fouled':
            'fouledPtn':
            'fouls':
            'foulsPtn':
            'goalSpdSh':
            'goalSpdShPtn':
            'goals':
            'goalsLost':
            'goalsLostPtn':
            'goalsPtn':
            'id':
            'interceptions':
            'interceptionsPtn':
            'keyPasses':
            'keyPassesPtn':
            'midThirdPass':
            'midThirdPassAcc':
            'midThirdPassSucc':
            'midThirdPassSuccPtn':
            'offsideWon':
            'offsideWonPtn':
            'offsides':
            'offsidesPtn':
            'passSucc':
            'passSuccPtn':
            'passes':
            'possession':
            'possessionPtn':
            'rate':
            'ratePtn':
            'redCards':
            'saves':
            'savesPtn':
            'season':
            'seriousError':
            'shots':
            'shotsConceded':
            'shotsConcededPtn':
            'shotsOT':
            'shotsOTPtn':
            'shotsPtn':
            'tackles':
            'tacklesPtn':
            'teamId':
            'teamIdWs':
            'updateTime':
            'yelCards':
'''

# %%
print(str.replace('\n', '\':').replace('            ','\'').replace(':',':\n'))
# Out:
# ':
# 'bigChanceCreatedPtn':
# 'bigChanceMissed':
# 'bigChanceMissedPtn':
# 'bigChanceScored':
# 'bigChanceScoredPtn':
# 'bigChanceSucc':
# 'bigChanceSuccPtn':
# 'cardPtn':
# 'clears':
# 'clearsPtn':
# 'competitionId':
# 'competitionIdWs':
# 'createTime':
# 'defensiveThirdPass':
# 'defensiveThirdPassAcc':
# 'defensiveThirdPassSucc':
# 'defensiveThirdPassSuccPtn':
# 'dribbles':
# 'dribblesPtn':
# 'errorsSum':
# 'errorsSumPtn':
# 'fatalError':
# 'finalThirdPass':
# 'finalThirdPassAcc':
# 'finalThirdPassSucc':
# 'finalThirdPassSuccPtn':
# 'fouled':
# 'fouledPtn':
# 'fouls':
# 'foulsPtn':
# 'goalSpdSh':
# 'goalSpdShPtn':
# 'goals':
# 'goalsLost':
# 'goalsLostPtn':
# 'goalsPtn':
# 'id':
# 'interceptions':
# 'interceptionsPtn':
# 'keyPasses':
# 'keyPassesPtn':
# 'midThirdPass':
# 'midThirdPassAcc':
# 'midThirdPassSucc':
# 'midThirdPassSuccPtn':
# 'offsideWon':
# 'offsideWonPtn':
# 'offsides':
# 'offsidesPtn':
# 'passSucc':
# 'passSuccPtn':
# 'passes':
# 'possession':
# 'possessionPtn':
# ...
