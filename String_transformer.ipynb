# %%
str = '''
            'aerialWon': 'aerialWon'
            'aerialWonPtn': 'aerialWonPtn'
            'apps': 'apps':
            'assists': 'assists'
            'assistsPtn': 'assistsPtn'
            'ballRecovery': 'ballRecovery'
            'ballRecoveryPtn': 'ballRecoveryPtn'
            'bigChanceCreated': 'bigChanceCreated'
            'bigChanceCreatedPtn': 'bigChanceCreatedPtn'
            'bigChanceMissed': 'bigChanceMissed'
            'bigChanceMissedPtn': 'bigChanceMissedPtn'
            'bigChanceScored': 'bigChanceScored'
            'bigChanceScoredPtn': 'bigChanceScoredPtn'
            'bigChanceSucc': 'bigChanceSucc'
            'bigChanceSuccPtn': 'bigChanceSuccPtn'
            'cardPtn': 'cardPtn'
            'clears': 'clears'
            'clearsPtn': 'clearsPtn'
            'competitionId': 'competitionId'
            'competitionIdWs': 'competitionIdWs'
            'createTime': 'createTime'
            'defensiveThirdPass': 'defensiveThirdPass'
            'defensiveThirdPassAcc': 'defensiveThirdPassAcc'
            'defensiveThirdPassSucc': 'defensiveThirdPassSucc'
            'defensiveThirdPassSuccPtn': 'defensiveThirdPassSuccPtn'
            'dribbles': 'dribbles'
            'dribblesPtn': 'dribblesPtn'
            'errorsSum': 'errorsSum'
            'errorsSumPtn': 'errorsSumPtn'
            'fatalError': 'fatalError'
            'finalThirdPass': 'finalThirdPass'
            'finalThirdPassAcc': 'finalThirdPassAcc'
            'finalThirdPassSucc': 'finalThirdPassSucc'
            'finalThirdPassSuccPtn': 'finalThirdPassSuccPtn'
            'fouled': 'fouled'
            'fouledPtn': 'fouledPtn'
            'fouls': 'fouls'
            'foulsPtn': 'foulsPtn'
            'goalSpdSh': 'goalSpdSh'
            'goalSpdShPtn': 'goalSpdShPtn'
            'goals': 'goals'
            'goalsLost': 'goalsLost'
            'goalsLostPtn': 'goalsLostPtn'
            'goalsPtn': 'goalsPtn'
            'id': 'id'
            'interceptions': 'interceptions'
            'interceptionsPtn': 'interceptionsPtn'
            'keyPasses': 'keyPasses'
            'keyPassesPtn': 'keyPassesPtn'
            'midThirdPass': 'midThirdPass'
            'midThirdPassAcc': 'midThirdPassAcc'
            'midThirdPassSucc': 'midThirdPassSucc'
            'midThirdPassSuccPtn': 'midThirdPassSuccPtn'
            'offsideWon': 'offsideWon'
            'offsideWonPtn': 'offsideWonPtn'
            'offsides': 'offsides'
            'offsidesPtn': 'offsidesPtn'
            'passSucc': 'passSucc'
            'passSuccPtn': 'passSuccPtn'
            'passes': 'passes'
            'possession': 'possession'
            'possessionPtn': 'possessionPtn'
            'rate': 'rate'
            'ratePtn': 'ratePtn'
            'redCards': 'redCards'
            'saves': 'saves'
            'savesPtn': 'savesPtn'
            'season': 'season'
            'seriousError': 'seriousError'
            'shots': 'shots'
            'shotsConceded': 'shotsConceded'
            'shotsConcededPtn': 'shotsConcededPtn'
            'shotsOT': 'shotsOT'
            'shotsOTPtn': 'shotsOTPtn'
            'shotsPtn': 'shotsPtn'
            'tackles': 'tackles'
            'tacklesPtn': 'tacklesPtn'
            'teamId': 'teamId'
            'teamIdWs': 'teamIdWs'
            'updateTime': 'updateTime'
            'yelCards': 'yelCards'
'''

# %%
print(str.replace('\n', '\':').replace('            ','\'').replace(':',':\n'))
# Out:
# ':
# 'bigChanceCreatedPtn':
# 'bigChanceMissed':
# 'bigChanceMissedPtn':
# 'bigChanceScored':
# 'bigChanceScoredPtn':
# 'bigChanceSucc':
# 'bigChanceSuccPtn':
# 'cardPtn':
# 'clears':
# 'clearsPtn':
# 'competitionId':
# 'competitionIdWs':
# 'createTime':
# 'defensiveThirdPass':
# 'defensiveThirdPassAcc':
# 'defensiveThirdPassSucc':
# 'defensiveThirdPassSuccPtn':
# 'dribbles':
# 'dribblesPtn':
# 'errorsSum':
# 'errorsSumPtn':
# 'fatalError':
# 'finalThirdPass':
# 'finalThirdPassAcc':
# 'finalThirdPassSucc':
# 'finalThirdPassSuccPtn':
# 'fouled':
# 'fouledPtn':
# 'fouls':
# 'foulsPtn':
# 'goalSpdSh':
# 'goalSpdShPtn':
# 'goals':
# 'goalsLost':
# 'goalsLostPtn':
# 'goalsPtn':
# 'id':
# 'interceptions':
# 'interceptionsPtn':
# 'keyPasses':
# 'keyPassesPtn':
# 'midThirdPass':
# 'midThirdPassAcc':
# 'midThirdPassSucc':
# 'midThirdPassSuccPtn':
# 'offsideWon':
# 'offsideWonPtn':
# 'offsides':
# 'offsidesPtn':
# 'passSucc':
# 'passSuccPtn':
# 'passes':
# 'possession':
# 'possessionPtn':
# 'rate':
# 'ratePtn':
# 'redCards':
# 'saves':
# 'savesPtn':
# 'season':
# 'seriousError':
# 'shots':
# 'shotsConceded':
# 'shotsConcededPtn':
# 'shotsOT':
# 'shotsOTPtn':
# 'shotsPtn':
# 'tackles':
# 'tacklesPtn':
# 'teamId':
# 'teamIdWs':
# 'updateTime':
# 'yelCards':

# %%
str.replace('\n',',')
# Out:
# ",            'aerialWon': 'aerialWon',            'aerialWonPtn': 'aerialWonPtn',            'apps': 'apps':,            'assists': 'assists',            'assistsPtn': 'assistsPtn',            'ballRecovery': 'ballRecovery',            'ballRecoveryPtn': 'ballRecoveryPtn',            'bigChanceCreated': 'bigChanceCreated',            'bigChanceCreatedPtn': 'bigChanceCreatedPtn',            'bigChanceMissed': 'bigChanceMissed',            'bigChanceMissedPtn': 'bigChanceMissedPtn',            'bigChanceScored': 'bigChanceScored',            'bigChanceScoredPtn': 'bigChanceScoredPtn',            'bigChanceSucc': 'bigChanceSucc',            'bigChanceSuccPtn': 'bigChanceSuccPtn',            'cardPtn': 'cardPtn',            'clears': 'clears',            'clearsPtn': 'clearsPtn',            'competitionId': 'competitionId',            'competitionIdWs': 'competitionIdWs',            'createTime': 'createTime',            'defensiveThirdPass': 'defensiveThirdPass',            'defensiveThirdPassAcc': 'defensiveThirdPassAcc',            'defensiveThirdPassSucc': 'defensiveThirdPassSucc',            'defensiveThirdPassSuccPtn': 'defensiveThirdPassSuccPtn',            'dribbles': 'dribbles',            'dribblesPtn': 'dribblesPtn',            'errorsSum': 'errorsSum',            'errorsSumPtn': 'errorsSumPtn',            'fatalError': 'fatalError',            'finalThirdPass': 'finalThirdPass',            'finalThirdPassAcc': 'finalThirdPassAcc',            'finalThirdPassSucc': 'finalThirdPassSucc',            'finalThirdPassSuccPtn': 'finalThirdPassSuccPtn',            'fouled': 'fouled',            'fouledPtn': 'fouledPtn',            'fouls': 'fouls',            'foulsPtn': 'foulsPtn',            'goalSpdSh': 'goalSpdSh',            'goalSpdShPtn': 'goalSpdShPtn',            'goals': 'goals',            'goalsLost': 'goalsLost',            'goalsLostPtn': 'goalsLostPtn',            'goalsPtn': 'goalsPtn',            'id': 'id',            'interceptions': 'interceptions',            'interceptionsPtn': 'interceptionsPtn',            'keyPasses': 'keyPasses',            'keyPassesPtn': 'keyPassesPtn',            'midThirdPass': 'midThirdPass',            'midThirdPassAcc': 'midThirdPassAcc',            'midThirdPassSucc': 'midThirdPassSucc',            'midThirdPassSuccPtn': 'midThirdPassSuccPtn',            'offsideWon': 'offsideWon',            'offsideWonPtn': 'offsideWonPtn',            'offsides': 'offsides',            'offsidesPtn': 'offsidesPtn',            'passSucc': 'passSucc',            'passSuccPtn': 'passSuccPtn',            'passes': 'passes',            'possession': 'possession',            'possessionPtn': 'possessionPtn',            'rate': 'rate',            'ratePtn': 'ratePtn',            'redCards': 'redCards',            'saves': 'saves',            'savesPtn': 'savesPtn',            'season': 'season',            'seriousError': 'seriousError',            'shots': 'shots',            'shotsConceded': 'shotsConceded',            'shotsConcededPtn': 'shotsConcededPtn',            'shotsOT': 'shotsOT',            'shotsOTPtn': 'shotsOTPtn',            'shotsPtn': 'shotsPtn',            'tackles': 'tackles',            'tacklesPtn': 'tacklesPtn',            'teamId': 'teamId',            'teamIdWs': 'teamIdWs',            'updateTime': 'updateTime',            'yelCards': 'yelCards',"
